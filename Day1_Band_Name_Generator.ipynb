# %%
print("Hola! Create your Band Name here")
city  = input("What is the name of city grew up in?")
petname = input("What is the name of your Pet?")
print("Your band could be: " + city +" " + petname)
# Out:
# Hola! Create your Band Name here
# What is the name of city grew up in?Begumpet
# What is the name of your Pet?Subbu
# Your band could be: Begumpet Subbu
